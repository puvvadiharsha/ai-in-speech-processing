# %%
pip install librosa

# %%
#A1
import librosa
y, sr= librosa.load("lab1.wav")
librosa.display.waveshow(y)

# %%
#A2
length = len(y) / sr
magnitude_range = max(abs(y)) - min(abs(y))


print(f"length: {duration} seconds")
print(f"Magnitude Range: {magnitude_range}")
# Out:
# length: 2.046666666666667 seconds
# Magnitude Range: 0.4717973470687866

# %%
#A3
import IPython.display as ipd
start = 1
end = 1.5
segment = y[int(start * sr):int(end * sr)]
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#A4
import IPython.display as ipd
start = 1
end = 1.2
segment = y[int(start * sr):int(end * sr)]
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
start = 1.5
end = 2
segment = y[int(start * sr):int(end * sr)]
ipd.Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start = 1
end = 1.8
y_abrupt = y.copy()
y_abrupt[int(start * sr):int(end * sr)] = 0
plt.figure(figsize=(10, 4))
plt.plot(y, label='Original')
plt.plot(y_abrupt, label='Abruptly Segmented')
plt.title('Original and Abruptly Segmented Speech Signals')
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.legend()
plt.show()
